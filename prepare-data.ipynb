# %%
import pandas as pd

# %%
# Load the four CSV files
df1 = pd.read_csv('combined_citibike.csv')

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6929648 entries, 0 to 6929647
# Data columns (total 15 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             int64
#  1   starttime                object
#  2   stoptime                 object
#  3   start station id         float64
#  4   start station name       object
#  5   start station latitude   float64
#  6   start station longitude  float64
#  7   end station id           float64
#  8   end station name         object
#  9   end station latitude     float64
#  10  end station longitude    float64
#  11  bikeid                   int64
#  12  usertype                 object
#  13  birth year               int64
#  14  gender                   int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 793.0+ MB

# %%
# Drop Null
df1.dropna()
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                 316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                 591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3                2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                 303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...               ...                       ...                       ...
# 6929643           304  2019-05-31 23:59:45.5760  2019-06-01 00:04:50.4620
# 6929644           324  2019-05-31 23:59:46.4650  2019-06-01 00:05:11.1630
# 6929645          1926  2019-05-31 23:59:51.5060  2019-06-01 00:31:58.3920
# 6929646          2047  2019-05-31 23:59:52.4170  2019-06-01 00:34:00.1970
# 6929647           964  2019-05-31 23:59:55.5500  2019-06-01 00:15:59.8680
#
#          start station id           start station name  \
# ...

# %%
# Drop rows where the trip duration is less than 90 seconds and where the start and end stations are the same
df1 = df1.loc[((df1["tripduration"]>90) & (df1["start station id"] != df1["end station id"])),:]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6751454 entries, 0 to 6929647
# Data columns (total 15 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             int64
#  1   starttime                object
#  2   stoptime                 object
#  3   start station id         float64
#  4   start station name       object
#  5   start station latitude   float64
#  6   start station longitude  float64
#  7   end station id           float64
#  8   end station name         object
#  9   end station latitude     float64
#  10  end station longitude    float64
#  11  bikeid                   int64
#  12  usertype                 object
#  13  birth year               int64
#  14  gender                   int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 824.2+ MB
